# %%
import numpy as np
import netCDF4 as nc

# %%
file_path_b1 = "D:\BaiduNetdiskDownload\data\\bohai\\2011-2014.nc"
file_path_b2 = "D:\BaiduNetdiskDownload\data\\bohai\\2015-2018.nc"
file_path_b3 = "D:\BaiduNetdiskDownload\data\\bohai\\2019-2020.nc"
file_path_d1 = "D:\BaiduNetdiskDownload\data\donghai\\2011-2014.nc"
file_path_d2 = "D:\BaiduNetdiskDownload\data\donghai\\2015-2018.nc"
file_path_d3 = "D:\BaiduNetdiskDownload\data\donghai\\2019-2020.nc"
file_path_n1 = "D:\BaiduNetdiskDownload\data\\nanhai\\2011-2014.nc"
file_path_n2 = "D:\BaiduNetdiskDownload\data\\nanhai\\2015-2018.nc"
file_path_n3 = "D:\BaiduNetdiskDownload\data\\nanhai\\2019-2020.nc"

file_obj_b1 = nc.Dataset(file_path_b1)
file_obj_b2 = nc.Dataset(file_path_b2)
file_obj_b3 = nc.Dataset(file_path_b3)
file_obj_d1 = nc.Dataset(file_path_d1)
file_obj_d2 = nc.Dataset(file_path_d2)
file_obj_d3 = nc.Dataset(file_path_d3)
file_obj_n1 = nc.Dataset(file_path_n1)
file_obj_n2 = nc.Dataset(file_path_n2)
file_obj_n3 = nc.Dataset(file_path_n3)

# %%
file_obj_b1.variables.keys()
# Out:
# dict_keys(['longitude', 'latitude', 'time', 'u10', 'v10', 'swh'])

# %%
swh_data_b1 = file_obj_b1.variables['swh'][:]
swh_data_b2 = file_obj_b2.variables['swh'][:]
swh_data_b3 = file_obj_b3.variables['swh'][:]
swh_data_d1 = file_obj_d1.variables['swh'][:]
swh_data_d2 = file_obj_d2.variables['swh'][:]
swh_data_d3 = file_obj_d3.variables['swh'][:]
swh_data_n1 = file_obj_n1.variables['swh'][:]
swh_data_n2 = file_obj_n2.variables['swh'][:]
swh_data_n3 = file_obj_n3.variables['swh'][:]

#swh_data_b = np.concatenate((swh_data_b1, swh_data_b2, swh_data_b3), axis=0)
#swh_data_d = np.concatenate((swh_data_d1, swh_data_d2, swh_data_d3), axis=0)
#swh_data_n = np.concatenate((swh_data_n1, swh_data_n2, swh_data_n3), axis=0)

# %%
# 使用 .shape 获取维度的大小
shape_b = swh_data_b1.variables
print("B数据的形状（维度大小）:", shape_b)

# %%
print(swh_data_b1.variables.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14836\1634975782.py in <module>
# ----> 1 print(swh_data_b1.variables.keys())
#
# AttributeError: 'MaskedArray' object has no attribute 'variables'

# %%
arr = np.array(swh_data_b1)
print(arr.shape)
# Out:
# (35064, 17, 21)

# %%
swh_data_b1[0]
# Out:
# masked_array(
#   data=[[--, --, --, --, --, --, --, --, --, --, --, --, --, --, --, --,
#          --, --, --, --, --],
#         [--, --, --, --, --, --, --, 1.1141219376182843,
#          1.7706333395863547, 1.665147363794445, 1.3231661484164332, --,
#          --, --, --, --, --, --, --, --, --],
#         [--, --, --, --, --, --, 1.2318683448070609, 1.9632531988905875,
#          2.4232121503516564, 2.03774110284891, --, --, --, --, --, --,
#          --, --, --, --, --],
#         [--, --, --, --, --, 1.399273354634719, 2.081462263867925,
#          2.609509019878889, 2.6815294156315526, --, --, --, --, --, --,
#          --, --, --, --, --, --],
#         [--, --, 0.8177896240449587, 0.9786403152013359,
#          1.4552549470506009, 2.0281795085519825, 2.558231114980044,
#          2.8123844601628907, 2.7311109086390073, 1.8065664278312594,
#          1.9991862871354926, --, --, --, --, --, --, --, --, --, --],
#         [--, --, 1.200099176659205, 1.4391390340823924,
# ...

# %%
import matplotlib.pyplot as plt
swh_data_b1 = swh_data_b1.flatten()
swh_data_b2 = swh_data_b2.flatten()
swh_data_b3 = swh_data_b3.flatten()
swh_data_d1 = swh_data_d1.flatten()
swh_data_d2 = swh_data_d2.flatten()
swh_data_d3 = swh_data_d3.flatten()
swh_data_n1 = swh_data_n1.flatten()
swh_data_n2 = swh_data_n2.flatten()
swh_data_n3 = swh_data_n3.flatten()
plt.hist(swh_data_b1, bins=30, edgecolor='black', label='波高')
plt.xlabel('Height')
plt.ylabel('times')
plt.title('B_2011-2014')
plt.savefig('B_2011-2014.png')
plt.show()


plt.hist(swh_data_b2, bins=30, edgecolor='black', label='波高')
plt.xlabel('Height')
plt.ylabel('times')
plt.title('B_2015-2018')
plt.savefig('B_2015-2018.png')
plt.show()


plt.hist(swh_data_b3, bins=30, edgecolor='black', label='波高')
plt.xlabel('Height')
plt.ylabel('times')
plt.title('B_2019-2020')
plt.savefig('B_2019-2020.png')
plt.show()


plt.hist(swh_data_d1, bins=30, edgecolor='black', label='波高')
plt.xlabel('Height')
plt.ylabel('times')
plt.title('D_2011-2014')
plt.savefig('D_2011-2014.png')
plt.show()


plt.hist(swh_data_d2, bins=30, edgecolor='black', label='波高')
plt.xlabel('Height')
plt.ylabel('times')
plt.title('D_2015-2018')
plt.savefig('D_2015-2018.png')
plt.show()


plt.hist(swh_data_d3, bins=30, edgecolor='black', label='波高')
plt.xlabel('Height')
plt.ylabel('times')
plt.title('D_2019-2020')
plt.savefig('D_2019-2020.png')
plt.show()


plt.hist(swh_data_n1, bins=30, edgecolor='black', label='波高')
plt.xlabel('Height')
plt.ylabel('times')
plt.title('N_2011-2014')
plt.savefig('N_2011-2014.png')
plt.show()


plt.hist(swh_data_n2, bins=30, edgecolor='black', label='波高')
plt.xlabel('Height')
plt.ylabel('times')
plt.title('N_2015-2018')
plt.savefig('N_2015-2018.png')
plt.show()


plt.hist(swh_data_n3, bins=30, edgecolor='black', label='波高')
plt.xlabel('Height')
plt.ylabel('times')
plt.title('N_2019-2020')
plt.savefig('N_2019-2020.png')
plt.show()
